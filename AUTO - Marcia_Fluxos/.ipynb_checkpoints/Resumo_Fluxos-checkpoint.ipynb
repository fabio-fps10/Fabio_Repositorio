# %%
import pandas as pd
from Funcoes_Excel import FUNCAO_AUTO_FULXO_MARCIA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from Funcoes_Excel import FUNCAO_AUTO_FULXO_MARCIA
#
# ModuleNotFoundError: No module named 'Funcoes_Excel'

# %%
mes_atual = 'mar'
ultimo_domingo = 17
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
dict_cru = {}
dict_MFs = {}
dict_I8 = {}
mes_obs = 'Março'

# %%
FUNCAO_AUTO_FULXO_MARCIA (mes_atual)
